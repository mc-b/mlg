# %% [markdown]
# ## Clustering – Beispiel k-Means
#
#
# Ein k-Means-Algorithmus ist ein Verfahren zur Vektorquantisierung, das auch zur Clusteranalyse verwendet wird. Dabei wird aus einer Menge von ähnlichen Objekten eine vorher bekannte Anzahl von k Gruppen gebildet. Der Algorithmus ist eine der am häufigsten verwendeten Techniken zur Gruppierung von Objekten, da er schnell die Zentren der Cluster findet. Dabei bevorzugt der Algorithmus Gruppen mit geringer Varianz, und ähnlicher Größe.
#
# Quelle: [Wikipedia](https://de.wikipedia.org/wiki/K-Means-Algorithmus)
#
# - - -
#
# **k-Means Clustering am Beispiel des Iris Datasets** (code von [Scikit-Learn](http://scikit-learn.org/stable/auto_examples/cluster/plot_cluster_iris.html#sphx-glr-auto-examples-cluster-plot-cluster-iris-py))

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris() # iris.data = Features
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# Anzahl Clusters (bei unsupervised learning nicht bekannt!)
set(iris.target) # iris.target = Label
# Out:
# {0, 1, 2}

# %%
# Code source: Gaël Varoquaux
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans

np.random.seed(5)

def plot_clusters(est, X):
    fig = plt.figure(1, figsize=(8, 6))
    plt.clf()
    ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

    plt.cla()
    est.fit(X)
    labels = est.labels_

    ax.scatter(X[:, 3], X[:, 0], X[:, 2], c=labels.astype(np.float))

    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_xlabel('Petal width')
    ax.set_ylabel('Sepal length')
    ax.set_zlabel('Petal length')
    plt.show()

# %%
# "korrekte" Anzahl von Cluster erraten
plot_clusters(KMeans(n_clusters=3), iris.data)

# %%
# "falsche" Anzahl von Cluster erraten
plot_clusters(KMeans(n_clusters=8), iris.data)
